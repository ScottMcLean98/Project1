# %%
import pandas as pd

# %%
path = "../Downloads/QuickFacts Feb-06-2023.csv"
csv_file = pd.read_csv(path, delimiter=',')

# %%
new_df = pd.DataFrame(csv_file)
new_df.head(20)
# Out:
#                                                  Fact Fact Note  \
# 0          Population Estimates, July 1 2022, (V2022)       NaN
# 1          Population Estimates, July 1 2021, (V2021)       NaN
# 2   Population estimates base, April 1, 2020, (V2022)       NaN
# 3   Population estimates base, April 1, 2020, (V2021)       NaN
# 4   Population, percent change - April 1, 2020 (es...       NaN
# 5   Population, percent change - April 1, 2020 (es...       NaN
# 6                   Population, Census, April 1, 2020       NaN
# 7                   Population, Census, April 1, 2010       NaN
# 8                      Persons under 5 years, percent       NaN
# 9                     Persons under 18 years, percent       NaN
# 10                 Persons 65 years and over, percent       NaN
# 11                            Female persons, percent       NaN
# 12                               White alone, percent       NaN
# 13           Black or African American alone, percent       (a)
# ...

# %%
population_df = pd.DataFrame(new_df["Seattle city, Washington"])
population_df = population_df.replace([',', '%'], '',regex=True).astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-135249cf43c3> in <module>
#       1 population_df = pd.DataFrame(new_df["Seattle city, Washington"])
# ----> 2 population_df = population_df.replace([',', '%'], '',regex=True).astype(float)
#
# ~\Bootcamp Anaconda\envs\PythonData\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\Bootcamp Anaconda\envs\PythonData\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# ...

# %%
pop_2020 = population_df["Seattle city, Washington"].values[3]
pop_2021 = population_df["Seattle city, Washington"].values[1]



#df=df.replace(',','',regex=True).astype(float)

#pop_change = pop_2020 - pop_2021
#pop_change

#print(f"The population percentage change between 2020 and 2021 is: " + (({pop_2020} - {pop_2021}) / {pop_2020}))
#perc_change = float((pop_2020 - pop_2021) / pop_2020)
#perc_change
# Out:
# '733,919'
